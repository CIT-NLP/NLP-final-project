# %% [markdown]
# <a href="https://colab.research.google.com/github/CIT-NLP/NLP-final-project/blob/main/Model_Building.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown https://drive.google.com/u/0/uc?id=1Ye6AqA9mikhqWbDYej0FH_e63fGsghXF
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1Ye6AqA9mikhqWbDYej0FH_e63fGsghXF
# To: /content/lemmmatized dataframe.csv
# 100% 145M/145M [00:01<00:00, 75.9MB/s]

# %% [markdown]
# # Downloading the dataframe

# %%
# !ls
# Out:
# 'lemmmatized dataframe.csv'   sample_data

# %%
import pandas as pd

df = pd.read_csv("./lemmmatized dataframe.csv")

df
# Out:
#        wikipedia id                                         movie name  \
# 0            975900                                     Ghosts of Mars
# 1          18998739                          The Sorcerer's Apprentice
# 2           6631279                                        Little city
# 3          11250635                            The Mechanical Monsters
# 4             77856                                       Mary Poppins
# ...             ...                                                ...
# 26083      26482675                                     Eşrefpaşalılar
# 26084      23851782                                    The Ghost Train
# 26085      34980460                                            Knuckle
# 26086        913762  The Super Dimension Fortress Macross II: Lover...
# 26087      12476867                                            Spliced
#
#                                                   genres  \
# 0      ['action', 'adventure', 'thriller', 'horror', ...
# 1      ['adventure', 'family', 'world cinema', 'fanta...
# 2                         ['drama', 'comedy', 'romance']
# 3      ['action', 'adventure', 'family', 'short film'...
# 4               ['drama', 'comedy', 'family', 'fantasy']
# ...                                                  ...
# 26083                                ['drama', 'comedy']
# 26084                    ['comedy', 'crime', 'thriller']
# 26085                           ['drama', 'documentary']
# 26086  ['drama', 'adventure', 'short film', 'science ...
# 26087                             ['thriller', 'horror']
#
#                                                  summary  \
# 0      Set in the second half of the 22nd century, th...
# 1      Every hundred years, the evil Morgana  returns...
# 2      Adam, a San Francisco-based artist who works a...
# 3       The story starts as one of the robots flies i...
# 4      The film opens with Mary Poppins  perched in a...
# ...                                                  ...
# 26083  The film is about two friends, Tayyar , a mafi...
# 26084  {{plot}} The film opens with a Great Western e...
# 26085  {{No plot}} This film follows 12 years in the ...
# 26086  The story takes place in the year 2092,The Sup...
# 26087  The movie is about a teenage girl who loves ho...
#
#                                                 unigrams  \
# 0      ['set', 'second', 'half', '22nd', 'century', '...
# 1      ['years', 'evil', 'morgana', 'returns', 'claim...
# 2      ['adam', 'san', 'francisco', 'based', 'artist'...
# 3      ['story', 'starts', 'robots', 'flies', 'scient...
# 4      ['film', 'opens', 'mary', 'poppins', 'perched'...
# ...                                                  ...
# 26083  ['film', 'friends', 'tayyar', 'mafia', 'leader...
# 26084  ['plot', 'film', 'opens', 'great', 'western', ...
# 26085  ['plot', 'film', 'follows', '12', 'years', 'li...
# 26086  ['story', 'takes', 'place', 'year', '2092,the'...
# 26087  ['movie', 'teenage', 'girl', 'loves', 'horror'...
#
#                                               lemmatized
# 0      ['set', 'second', 'half', '22nd', 'century', '...
# 1      ['year', 'evil', 'Morgana', 'return', 'claim',...
# 2      ['Adam', 'San', 'Francisco', 'base', 'artist',...
# 3      ['story', 'start', 'robot', 'fly', 'scientist'...
# 4      ['film', 'open', 'Mary', 'Poppins', 'perch', '...
# ...                                                  ...
# 26083  ['film', 'friend', 'Tayyar', 'mafia', 'leader'...
# 26084  ['plot', 'film', 'open', 'great', 'western', '...
# 26085  ['plot', 'film', 'follow', '12', 'year', 'life...
# 26086  ['story', 'take', 'place', 'year', '2092,the',...
# 26087  ['movie', 'teenage', 'girl', 'love', 'horror',...
#
# [26088 rows x 6 columns]
