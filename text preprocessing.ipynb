# %% [markdown]
# ## Downloading the Dataset

# %%
# !gdown https://drive.google.com/u/0/uc?id=1v9u3NTeJtlIYdNGLqMa2kZNTGjMCvjjh
# Out:
# Downloading...
# From: https://drive.google.com/u/0/uc?id=1v9u3NTeJtlIYdNGLqMa2kZNTGjMCvjjh
# To: /content/MovieSummaries.tar
# 100% 134M/134M [00:01<00:00, 99.7MB/s]

# %%
# !ls
# Out:
# MovieSummaries.tar  sample_data

# %%
# !tar -xf MovieSummaries.tar && ls
# Out:
# MovieSummaries	MovieSummaries.tar  sample_data

# %% [markdown]
# # Loading and Cleaning

# %%
import pandas as pd

# %%
#reading file with genres
columns = ["wikipedia id", "freebase id", "movie name", "year released", "revenue", "runtime", "language", "country released", "genres"]
metadata = pd.read_csv("./MovieSummaries/movie.metadata.tsv", sep = "\t", header=None, names = columns)

metadata
# Out:
#        wikipedia id freebase id  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 2          28463795  /m/0crgdbh
# 3           9363483  /m/0285_cd
# 4            261236   /m/01mrr1
# ...             ...         ...
# 81736      35228177  /m/0j7hxnt
# 81737      34980460  /m/0g4pl34
# 81738       9971909  /m/02pygw1
# 81739        913762   /m/03pcrp
# 81740      12476867  /m/02w7zz8
#
#                                               movie name year released  \
# 0                                         Ghosts of Mars    2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...    2000-02-16
# 2                                            Brun bitter          1988
# 3                                       White Of The Eye          1987
# 4                                      A Woman in Flames          1983
# ...                                                  ...           ...
# 81736                           Mermaids: The Body Found    2011-03-19
# 81737                                            Knuckle    2011-01-21
# 81738                                  Another Nice Mess    1972-09-22
# 81739  The Super Dimension Fortress Macross II: Lover...    1992-05-21
# 81740                                            Spliced          2002
#
#           revenue  runtime                            language  \
# 0      14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1             NaN     95.0  {"/m/02h40lc": "English Language"}
# 2             NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3             NaN    110.0  {"/m/02h40lc": "English Language"}
# 4             NaN    106.0   {"/m/04306rv": "German Language"}
# ...           ...      ...                                 ...
# 81736         NaN    120.0  {"/m/02h40lc": "English Language"}
# 81737         NaN     96.0  {"/m/02h40lc": "English Language"}
# 81738         NaN     66.0  {"/m/02h40lc": "English Language"}
# 81739         NaN    150.0   {"/m/03_9r": "Japanese Language"}
# 81740         NaN     86.0  {"/m/02h40lc": "English Language"}
#
#                                         country released  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 2                                 {"/m/05b4w": "Norway"}
# 3                         {"/m/07ssc": "United Kingdom"}
# 4                                {"/m/0345h": "Germany"}
# ...                                                  ...
# 81736          {"/m/09c7w0": "United States of America"}
# 81737  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 81738          {"/m/09c7w0": "United States of America"}
# 81739                              {"/m/03_3d": "Japan"}
# 81740                            {"/m/0d060g": "Canada"}
#
#                                                   genres
# 0      {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1      {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2      {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3      {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                                {"/m/07s9rl0": "Drama"}
# ...                                                  ...
# 81736                            {"/m/07s9rl0": "Drama"}
# 81737  {"/m/03bxz7": "Biographical film", "/m/07s9rl0...
# 81738       {"/m/06nbt": "Satire", "/m/01z4y": "Comedy"}
# 81739  {"/m/06n90": "Science Fiction", "/m/0gw5n2f": ...
# 81740  {"/m/01jfsb": "Thriller", "/m/03npn": "Horror"...
#
# [81741 rows x 9 columns]

# %%
import json
#genres column is in json format, so load column as dictionary
metadata.genres = metadata.genres.apply(json.loads)

#get only genres in each dictionary for each row
metadata.genres = metadata.genres.apply(lambda x : list(x.values()))

metadata
# Out:
#        wikipedia id freebase id  \
# 0            975900   /m/03vyhn
# 1           3196793   /m/08yl5d
# 2          28463795  /m/0crgdbh
# 3           9363483  /m/0285_cd
# 4            261236   /m/01mrr1
# ...             ...         ...
# 81736      35228177  /m/0j7hxnt
# 81737      34980460  /m/0g4pl34
# 81738       9971909  /m/02pygw1
# 81739        913762   /m/03pcrp
# 81740      12476867  /m/02w7zz8
#
#                                               movie name year released  \
# 0                                         Ghosts of Mars    2001-08-24
# 1      Getting Away with Murder: The JonBenét Ramsey ...    2000-02-16
# 2                                            Brun bitter          1988
# 3                                       White Of The Eye          1987
# 4                                      A Woman in Flames          1983
# ...                                                  ...           ...
# 81736                           Mermaids: The Body Found    2011-03-19
# 81737                                            Knuckle    2011-01-21
# 81738                                  Another Nice Mess    1972-09-22
# 81739  The Super Dimension Fortress Macross II: Lover...    1992-05-21
# 81740                                            Spliced          2002
#
#           revenue  runtime                            language  \
# 0      14010832.0     98.0  {"/m/02h40lc": "English Language"}
# 1             NaN     95.0  {"/m/02h40lc": "English Language"}
# 2             NaN     83.0  {"/m/05f_3": "Norwegian Language"}
# 3             NaN    110.0  {"/m/02h40lc": "English Language"}
# 4             NaN    106.0   {"/m/04306rv": "German Language"}
# ...           ...      ...                                 ...
# 81736         NaN    120.0  {"/m/02h40lc": "English Language"}
# 81737         NaN     96.0  {"/m/02h40lc": "English Language"}
# 81738         NaN     66.0  {"/m/02h40lc": "English Language"}
# 81739         NaN    150.0   {"/m/03_9r": "Japanese Language"}
# 81740         NaN     86.0  {"/m/02h40lc": "English Language"}
#
#                                         country released  \
# 0              {"/m/09c7w0": "United States of America"}
# 1              {"/m/09c7w0": "United States of America"}
# 2                                 {"/m/05b4w": "Norway"}
# 3                         {"/m/07ssc": "United Kingdom"}
# 4                                {"/m/0345h": "Germany"}
# ...                                                  ...
# 81736          {"/m/09c7w0": "United States of America"}
# 81737  {"/m/03rt9": "Ireland", "/m/07ssc": "United Ki...
# 81738          {"/m/09c7w0": "United States of America"}
# 81739                              {"/m/03_3d": "Japan"}
# 81740                            {"/m/0d060g": "Canada"}
#
#                                                   genres
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 2                                 [Crime Fiction, Drama]
# 3      [Thriller, Erotic thriller, Psychological thri...
# 4                                                [Drama]
# ...                                                  ...
# 81736                                            [Drama]
# 81737            [Biographical film, Drama, Documentary]
# 81738                                   [Satire, Comedy]
# 81739  [Science Fiction, Japanese Movies, Adventure, ...
# 81740                  [Thriller, Horror, Slasher, Teen]
#
# [81741 rows x 9 columns]

# %%
#reading summary file
columns = ["wikipedia id", "summary"]
summ = pd.read_csv("./MovieSummaries/plot_summaries.txt", sep = "\t", header=None, names = columns)

summ
# Out:
#        wikipedia id                                            summary
# 0          23890098  Shlykov, a hard-working taxi driver and Lyosha...
# 1          31186339  The nation of Panem consists of a wealthy Capi...
# 2          20663735  Poovalli Induchoodan  is sentenced for six yea...
# 3           2231378  The Lemon Drop Kid , a New York City swindler,...
# 4            595909  Seventh-day Adventist Church pastor Michael Ch...
# ...             ...                                                ...
# 42298      34808485  The story is about Reema , a young Muslim scho...
# 42299       1096473  In 1928 Hollywood, director Leo Andreyev  look...
# 42300      35102018  American Luthier focuses on Randy Parsons’ tra...
# 42301       8628195  Abdur Rehman Khan , a middle-aged dry fruit se...
# 42302       6040782  1940 - Operation Dynamo has just taken place. ...
#
# [42303 rows x 2 columns]

# %%
#drop unneeded columns
meta = metadata.drop(["freebase id", "year released", "revenue", "runtime", "country released", 'language'], axis=1)

#merge dataframes with genres and summaries 
df = pd.merge(meta, summ, how="inner", on="wikipedia id")

df
# Out:
#        wikipedia id                                         movie name  \
# 0            975900                                     Ghosts of Mars
# 1           9363483                                   White Of The Eye
# 2            261236                                  A Woman in Flames
# 3          18998739                          The Sorcerer's Apprentice
# 4           6631279                                        Little city
# ...             ...                                                ...
# 42199      23851782                                    The Ghost Train
# 42200      35228177                           Mermaids: The Body Found
# 42201      34980460                                            Knuckle
# 42202        913762  The Super Dimension Fortress Macross II: Lover...
# 42203      12476867                                            Spliced
#
#                                                   genres  \
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1      [Thriller, Erotic thriller, Psychological thri...
# 2                                                [Drama]
# 3        [Family Film, Fantasy, Adventure, World cinema]
# 4      [Romantic comedy, Ensemble Film, Comedy-drama,...
# ...                                                  ...
# 42199    [Crime Fiction, Thriller, Comedy, Supernatural]
# 42200                                            [Drama]
# 42201            [Biographical film, Drama, Documentary]
# 42202  [Science Fiction, Japanese Movies, Adventure, ...
# 42203                  [Thriller, Horror, Slasher, Teen]
#
#                                                  summary
# 0      Set in the second half of the 22nd century, th...
# 1      A series of murders of rich young women throug...
# 2      Eva, an upper class housewife, becomes frustra...
# 3      Every hundred years, the evil Morgana  returns...
# 4      Adam, a San Francisco-based artist who works a...
# ...                                                  ...
# 42199  {{plot}} The film opens with a Great Western e...
# 42200  Two former National Oceanic Atmospheric Admini...
# 42201  {{No plot}} This film follows 12 years in the ...
# 42202  The story takes place in the year 2092,The Sup...
# 42203  The movie is about a teenage girl who loves ho...
#
# [42204 rows x 4 columns]

# %%
from collections import Counter 

genre_counter = Counter()

df.genres.apply(genre_counter.update)

genre_counter
# Out:
# Counter({'Thriller': 6530,
#          'Science Fiction': 2339,
#          'Horror': 4082,
#          'Adventure': 3248,
#          'Supernatural': 571,
#          'Action': 5868,
#          'Space western': 12,
#          'Erotic thriller': 170,
#          'Psychological thriller': 1138,
#          'Drama': 19134,
#          'Family Film': 3219,
#          'Fantasy': 2012,
#          'World cinema': 5153,
#          'Romantic comedy': 2075,
#          'Ensemble Film': 349,
#          'Comedy-drama': 1261,
#          'Comedy': 10467,
#          'Romantic drama': 2572,
#          'Romance Film': 6666,
#          'Costume drama': 367,
#          'War film': 1556,
#          'Epic': 196,
#          'Period piece': 1321,
#          'Film adaptation': 1225,
#          'Animation': 2441,
#          'Short Film': 3192,
#          "Children's/Family": 759,
#          'Musical': 2414,
#          "Children's Fantasy": 244,
#          'Indie': 3668,
#          'Crime Fiction': 4275,
#          'Coming of age': 741,
#          'Bollywood': 1058,
#          'Fan film': 18,
#          'Black comedy': 834,
#          'Action/Adventure': 3553,
#          'Cult': 680,
#          'Adventure Comedy': 123,
#          'Slapstick': 518,
#          'Sports': 672,
#          'Family Drama': 766,
#          'Biographical film': 625,
#          'Historical fiction': 305,
#          'Black-and-white': 3731,
#          'Biopic [feature]': 365,
#          'Culture & Society': 204,
#          'Biography': 592,
#          'Documentary': 1213,
#          'Christmas movie': 80,
#          'Television movie': 665,
#          'Action Comedy': 142,
#          'Blaxploitation': 79,
#          'Martial Arts Film': 706,
#          'Erotica': 235,
#          'Sci-Fi Horror': 124,
#          'Satire': 532,
#          'Western': 1022,
#          'Softcore Porn': 41,
#          'Sexploitation': 82,
#          'Mystery': 2119,
#          'Crime Thriller': 1682,
#          'Action Thrillers': 405,
#          'Suspense': 651,
#          'Musical Drama': 136,
#          'Erotic Drama': 112,
#          'Japanese Movies': 1290,
#          'Pornographic movie': 145,
#          'Comedy film': 1778,
#          'Slasher': 654,
#          'Film noir': 524,
#          'Legal drama': 8,
#          'Courtroom Drama': 184,
#          'New Hollywood': 86,
#          'Experimental film': 107,
#          'Surrealism': 99,
#          'Tragicomedy': 51,
#          'Avant-garde': 83,
#          'Crime Comedy': 231,
#          'Gangster Film': 338,
#          'Fantasy Comedy': 196,
#          'Monster movie': 168,
#          'Natural horror films': 153,
#          'B-movie': 386,
#          'Creature Film': 347,
#          'Music': 356,
#          'Comedy of Errors': 169,
#          'Melodrama': 499,
#          'Americana': 91,
#          'Detective fiction': 225,
#          'Detective': 282,
#          'Horror Comedy': 206,
#          'Anime': 305,
#          'Childhood Drama': 111,
#          'Docudrama': 252,
#          'LGBT': 825,
#          'Teen': 824,
#          'Gothic Film': 62,
#          'Disaster': 238,
#          'Domestic Comedy': 172,
#          'Escape Film': 45,
#          'Prison': 90,
#          'Superhero movie': 258,
#          'Filipino Movies': 220,
#          'Filipino': 10,
#          'Spy': 342,
#          'Combat Films': 84,
#          'Wuxia': 79,
#          'Fantasy Adventure': 190,
#          'Chinese Movies': 998,
#          'Parody': 767,
#          'Comedy horror': 19,
#          'C-Movie': 1,
#          'Dystopia': 84,
#          'Buddy film': 325,
#          'Tragedy': 79,
#          'Time travel': 77,
#          'Sword and sorcery': 39,
#          'Silent film': 1199,
#          'Political cinema': 176,
#          'Political satire': 78,
#          'Gross-out film': 58,
#          'Gross out': 58,
#          'Historical drama': 107,
#          'Marriage Drama': 137,
#          'Crime Drama': 391,
#          'Historical Epic': 63,
#          'Screwball comedy': 246,
#          'Zombie Film': 234,
#          'Gay': 219,
#          'Gay Interest': 217,
#          'Gay Themed': 264,
#          'History': 358,
#          'Political drama': 531,
#          'Art film': 351,
#          'Medical fiction': 56,
#          'Costume Adventure': 77,
#          'Feminist Film': 76,
#          'Educational': 16,
#          'Film à clef': 29,
#          'Costume Horror': 55,
#          'Juvenile Delinquency Film': 42,
#          'Natural disaster': 14,
#          'Linguistics': 1,
#          'Language & Literature': 8,
#          'Pre-Code': 130,
#          'Comedy of manners': 212,
#          'Musical comedy': 175,
#          "Children's": 412,
#          'Family-Oriented Adventure': 213,
#          'Remake': 85,
#          'Media Satire': 71,
#          'Computer Animation': 195,
#          'Spaghetti Western': 56,
#          'Dogme 95': 17,
#          'Political thriller': 195,
#          'Hybrid Western': 29,
#          'Stop motion': 134,
#          'Mockumentary': 97,
#          'Roadshow theatrical release': 32,
#          'Sex comedy': 253,
#          'Tollywood': 32,
#          'Women in prison films': 13,
#          'Holiday Film': 94,
#          'Heavenly Comedy': 27,
#          'Road movie': 268,
#          'Giallo': 25,
#          'Existentialism': 34,
#          'Social problem film': 92,
#          'Propaganda film': 77,
#          'Auto racing': 50,
#          'Slice of life story': 94,
#          'Kitchen sink realism': 14,
#          'British New Wave': 13,
#          'Heist': 145,
#          'Gulf War': 5,
#          'Archaeology': 10,
#          'Romantic fantasy': 59,
#          'Religious Film': 61,
#          'Biker Film': 20,
#          'Animal Picture': 141,
#          'Absurdism': 79,
#          'Swashbuckler films': 104,
#          'Hagiography': 19,
#          'Dance': 69,
#          'Hardcore pornography': 7,
#          'Adult': 117,
#          'Animated Musical': 43,
#          'Anti-war': 32,
#          'Anti-war film': 31,
#          'Cavalry Film': 12,
#          'Space opera': 5,
#          'Czechoslovak New Wave': 7,
#          'Malayalam Cinema': 12,
#          'Doomsday film': 112,
#          'Animals': 15,
#          'Addiction Drama': 42,
#          'Comedy Western': 53,
#          'Chase Movie': 100,
#          'Tokusatsu': 2,
#          'Pornography': 7,
#          'Gay pornography': 21,
#          'Superhero': 111,
#          'Christian film': 116,
#          'Apocalyptic and post-apocalyptic fiction': 32,
#          'Whodunit': 43,
#          'Future noir': 29,
#          'Airplanes and airports': 53,
#          'Social issues': 101,
#          'Law & Crime': 21,
#          'Alien Film': 97,
#          'Animated cartoon': 94,
#          'Revisionist Western': 60,
#          'Jungle Film': 62,
#          'Comedy Thriller': 78,
#          'Tamil cinema': 63,
#          'Libraries and librarians': 5,
#          'Workplace Comedy': 84,
#          'Caper story': 80,
#          'Demonic child': 6,
#          'Inspirational Drama': 27,
#          'Glamorized Spy Film': 45,
#          'Interpersonal Relationships': 21,
#          'Illnesses & Disabilities': 14,
#          'British Empire Film': 20,
#          'Monster': 113,
#          'Samurai cinema': 27,
#          'Sword and sorcery films': 37,
#          'B-Western': 19,
#          'Concert film': 11,
#          'Humour': 4,
#          'Haunted House Film': 65,
#          'Roadshow/Carny': 4,
#          'Exploitation': 12,
#          'Mumblecore': 7,
#          "Children's Entertainment": 11,
#          'Splatter film': 28,
#          'Epic Western': 17,
#          'Star vehicle': 2,
#          'Sword and Sandal': 16,
#          'Mythological Fantasy': 26,
#          'Camp': 3,
#          'Hip hop movies': 31,
#          'Latino': 3,
#          'Sci-Fi Adventure': 32,
#          'Boxing': 51,
#          'Gender Issues': 19,
#          'Revenge': 2,
#          'Foreign legion': 10,
#          'Historical Documentaries': 2,
#          'Heaven-Can-Wait Fantasies': 21,
#          'Stoner film': 46,
#          'Rockumentary': 40,
#          'Conspiracy fiction': 2,
#          'Fairy tale': 48,
#          'Sponsored film': 4,
#          'Crime': 26,
#          'Master Criminal Films': 25,
#          'Jukebox musical': 7,
#          'Stand-up comedy': 12,
#          'Indian Western': 18,
#          'Mondo film': 5,
#          'Road-Horror': 19,
#          'Werewolf fiction': 4,
#          'Neo-noir': 57,
#          'Private military company': 2,
#          'Backstage Musical': 20,
#          'Movies About Gladiators': 5,
#          'Horse racing': 8,
#          'Nuclear warfare': 3,
#          'Essay Film': 8,
#          'Instrumental Music': 4,
#          'Media Studies': 7,
#          'Psycho-biddy': 10,
#          'Business': 4,
#          'Feature film': 8,
#          'Movie serial': 11,
#          'Outlaw biker film': 12,
#          'Prison escape': 2,
#          'Z movie': 2,
#          'News': 7,
#          'Beach Film': 19,
#          'Computers': 4,
#          'Live action': 2,
#          'Fictional film': 8,
#          'Education': 3,
#          'Period Horror': 2,
#          'Comdedy': 1,
#          'Punk rock': 23,
#          'Science fiction Western': 5,
#          'Bloopers & Candid Camera': 3,
#          'Graphic & Applied Arts': 4,
#          'Pinku eiga': 24,
#          'Psychological horror': 3,
#          'Albino bias': 14,
#          'Family & Personal Relationships': 10,
#          'Travel': 14,
#          'Steampunk': 30,
#          'Baseball': 9,
#          'Buddy cop': 11,
#          'Filmed Play': 3,
#          'Plague': 4,
#          'Fantasy Drama': 16,
#          'Sci-Fi Thriller': 5,
#          'Courtroom Comedy': 6,
#          'Operetta': 4,
#          'Prison film': 12,
#          'Parkour in popular culture': 6,
#          'Extreme Sports': 10,
#          'Early Black Cinema': 6,
#          'Cyberpunk': 5,
#          'Coming-of-age film': 4,
#          'Cold War': 10,
#          'Political Documetary': 1,
#          'Inventions & Innovations': 4,
#          'Bruceploitation': 3,
#          'Bengali Cinema': 10,
#          "Children's Issues": 1,
#          'Ealing Comedies': 12,
#          'Anthropology': 2,
#          'Silhouette animation': 1,
#          'Film & Television History': 11,
#          'Film': 19,
#          'Female buddy film': 4,
#          'Race movie': 3,
#          'Breakdance': 1,
#          'Acid western': 7,
#          'War effort': 1,
#          'Reboot': 8,
#          'School story': 4,
#          'Nature': 17,
#          'Clay animation': 4,
#          'Health & Fitness': 3,
#          'Environmental Science': 6,
#          'Supermarionation': 3,
#          'Sci Fi Pictures original films': 4,
#          'Outlaw': 5,
#          'Kafkaesque': 6,
#          'Vampire movies': 3,
#          'Northern': 7,
#          'Archives and records': 6,
#          'World History': 10,
#          'Goat gland': 4,
#          'Therimin music': 4,
#          'Beach Party film': 2,
#          'Point of view shot': 3,
#          'Romantic thriller': 1,
#          'Patriotic film': 1,
#          'Film-Opera': 3,
#          'Anthology': 7,
#          'Chick flick': 1,
#          'Ninja movie': 1,
#          'Alien invasion': 4,
#          'Singing cowboy': 3,
#          'Buddy Picture': 1,
#          'Journalism': 2,
#          'Statutory rape': 1,
#          'Expressionism': 2,
#          'Finance & Investing': 4,
#          'New Queer Cinema': 1,
#          'Neorealism': 1,
#          'The Netherlands in World War II': 2,
#          'Revisionist Fairy Tale': 2,
#          'Homoeroticism': 1})

# %%
genre_counter.most_common(35)
# Out:
# [('Drama', 19134),
#  ('Comedy', 10467),
#  ('Romance Film', 6666),
#  ('Thriller', 6530),
#  ('Action', 5868),
#  ('World cinema', 5153),
#  ('Crime Fiction', 4275),
#  ('Horror', 4082),
#  ('Black-and-white', 3731),
#  ('Indie', 3668),
#  ('Action/Adventure', 3553),
#  ('Adventure', 3248),
#  ('Family Film', 3219),
#  ('Short Film', 3192),
#  ('Romantic drama', 2572),
#  ('Animation', 2441),
#  ('Musical', 2414),
#  ('Science Fiction', 2339),
#  ('Mystery', 2119),
#  ('Romantic comedy', 2075),
#  ('Fantasy', 2012),
#  ('Comedy film', 1778),
#  ('Crime Thriller', 1682),
#  ('War film', 1556),
#  ('Period piece', 1321),
#  ('Japanese Movies', 1290),
#  ('Comedy-drama', 1261),
#  ('Film adaptation', 1225),
#  ('Documentary', 1213),
#  ('Silent film', 1199),
#  ('Psychological thriller', 1138),
#  ('Bollywood', 1058),
#  ('Western', 1022),
#  ('Chinese Movies', 998),
#  ('Black comedy', 834)]

# %%
#lowercase genres 
def genre_lower(genre_l):
    for i in range(len(genre_l)):
        genre_l[i] = genre_l[i].lower()
    return genre_l

df.genres = df.genres.apply(genre_lower)

df
# Out:
#        wikipedia id                                         movie name  \
# 0            975900                                     Ghosts of Mars
# 1           9363483                                   White Of The Eye
# 2            261236                                  A Woman in Flames
# 3          18998739                          The Sorcerer's Apprentice
# 4           6631279                                        Little city
# ...             ...                                                ...
# 42199      23851782                                    The Ghost Train
# 42200      35228177                           Mermaids: The Body Found
# 42201      34980460                                            Knuckle
# 42202        913762  The Super Dimension Fortress Macross II: Lover...
# 42203      12476867                                            Spliced
#
#                                                   genres  \
# 0      [thriller, science fiction, horror, adventure,...
# 1      [thriller, erotic thriller, psychological thri...
# 2                                                [drama]
# 3        [family film, fantasy, adventure, world cinema]
# 4      [romantic comedy, ensemble film, comedy-drama,...
# ...                                                  ...
# 42199    [crime fiction, thriller, comedy, supernatural]
# 42200                                            [drama]
# 42201            [biographical film, drama, documentary]
# 42202  [science fiction, japanese movies, adventure, ...
# 42203                  [thriller, horror, slasher, teen]
#
#                                                  summary
# 0      Set in the second half of the 22nd century, th...
# 1      A series of murders of rich young women throug...
# 2      Eva, an upper class housewife, becomes frustra...
# 3      Every hundred years, the evil Morgana  returns...
# 4      Adam, a San Francisco-based artist who works a...
# ...                                                  ...
# 42199  {{plot}} The film opens with a Great Western e...
# 42200  Two former National Oceanic Atmospheric Admini...
# 42201  {{No plot}} This film follows 12 years in the ...
# 42202  The story takes place in the year 2092,The Sup...
# 42203  The movie is about a teenage girl who loves ho...
#
# [42204 rows x 4 columns]

# %%
import re

# targets 
regex_list = ['drama', 'comedy', 'action', 'adventure', 'roman', 'crime',
              'thriller', 'family', 'world cinema', 'horror',
              'short film', 'science fiction', 'mystery', 
              'fantasy', 'documentary', 'silent film']

# compiled regex
compiled_regex = [re.compile(regex) for regex in regex_list]


# collapse genres to only include those in targets
def collapse_genres(genres, regex_list, compiled_regex):
  new_gen_l = []

  for i, co_regex in enumerate(compiled_regex): 
    found = list(filter(co_regex.match, genres))
    if found: 
      if regex_list[i] == 'roman': 
        new_gen_l.append('romance')
      else: 
        new_gen_l.append(regex_list[i])

  return new_gen_l
   

df.genres = df.genres.apply(lambda l: collapse_genres(l, regex_list, compiled_regex))

# remove rows with empty genre lists 
df = df[df.genres.astype(bool)]


# remove rows with only one genre listed
df = df[df.genres.map(len) > 1]

df
# Out:
#        wikipedia id                                         movie name  \
# 0            975900                                     Ghosts of Mars
# 3          18998739                          The Sorcerer's Apprentice
# 4           6631279                                        Little city
# 7          11250635                            The Mechanical Monsters
# 8             77856                                       Mary Poppins
# ...             ...                                                ...
# 42198      26482675                                     Eşrefpaşalılar
# 42199      23851782                                    The Ghost Train
# 42201      34980460                                            Knuckle
# 42202        913762  The Super Dimension Fortress Macross II: Lover...
# 42203      12476867                                            Spliced
#
#                                                   genres  \
# 0      [action, adventure, thriller, horror, science ...
# 3             [adventure, family, world cinema, fantasy]
# 4                               [drama, comedy, romance]
# 7      [action, adventure, family, short film, scienc...
# 8                       [drama, comedy, family, fantasy]
# ...                                                  ...
# 42198                                    [drama, comedy]
# 42199                          [comedy, crime, thriller]
# 42201                               [drama, documentary]
# 42202    [drama, adventure, short film, science fiction]
# 42203                                 [thriller, horror]
#
#                                                  summary
# 0      Set in the second half of the 22nd century, th...
# 3      Every hundred years, the evil Morgana  returns...
# 4      Adam, a San Francisco-based artist who works a...
# 7       The story starts as one of the robots flies i...
# 8      The film opens with Mary Poppins  perched in a...
# ...                                                  ...
# 42198  The film is about two friends, Tayyar , a mafi...
# 42199  {{plot}} The film opens with a Great Western e...
# 42201  {{No plot}} This film follows 12 years in the ...
# 42202  The story takes place in the year 2092,The Sup...
# 42203  The movie is about a teenage girl who loves ho...
#
# [26088 rows x 4 columns]

# %%
# genre counts following cleaning 
count = Counter()
df.genres.apply(count.update)

count.most_common()
# Out:
# [('drama', 14211),
#  ('comedy', 9773),
#  ('romance', 6678),
#  ('thriller', 6166),
#  ('action', 6035),
#  ('world cinema', 5031),
#  ('crime', 4997),
#  ('family', 3554),
#  ('adventure', 3096),
#  ('horror', 2778),
#  ('short film', 2270),
#  ('science fiction', 2148),
#  ('mystery', 2060),
#  ('fantasy', 1996),
#  ('silent film', 810),
#  ('documentary', 402)]

# %%
# genre stats
df3gencs = []
for genre in df.genres:
    c = 0
    for el in genre:
        c += 1
    df3gencs.append(c)

df3countsCounter = Counter(df3gencs)
df3countsCounter.most_common()
# Out:
# [(2, 12793),
#  (3, 8449),
#  (4, 3512),
#  (5, 1034),
#  (6, 254),
#  (7, 39),
#  (8, 6),
#  (9, 1)]

# %% [markdown]
# ## Text Preparation

# %%
# !pip install -Uqq spacy
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.3.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.3.0/en_core_web_sm-3.3.0-py3-none-any.whl (12.8 MB)
# Requirement already satisfied: spacy<3.4.0,>=3.3.0.dev0 in c:\users\pc\anaconda3\lib\site-packages (from en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: thinc<8.1.0,>=8.0.14 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.15)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.9 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.9)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.20.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (21.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.26.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.6)
# Requirement already satisfied: jinja2 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.11.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.7.7)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (4.62.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.6.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.9.1 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.9.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.2)
# Requirement already satisfied: setuptools in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (58.0.4)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.3.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.0.7)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\pc\anaconda3\lib\site-packages (from spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.7)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\pc\anaconda3\lib\site-packages (from packaging>=20.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.0.4)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\pc\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\pc\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.10.0.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (3.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\pc\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (2.0.4)
# Requirement already satisfied: colorama in c:\users\pc\anaconda3\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (0.4.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\pc\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (8.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\pc\anaconda3\lib\site-packages (from jinja2->spacy<3.4.0,>=3.3.0.dev0->en-core-web-sm==3.3.0) (1.1.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.3.0
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# 2022-05-08 17:57:01.036290: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'cudart64_110.dll'; dlerror: cudart64_110.dll not found
# 2022-05-08 17:57:01.036730: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
import spacy

spacy.__version__
# Out:
# '3.3.0'

# %%
nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'attribute_ruler', 'lemmatizer']

# %%
# looking at example summary 
df.iloc[10]['summary']
# Out:
# 'The film is a collision of three separate stories—the journey of a Ju/\'hoansi Bushman to the end of the earth to get rid of a Coca-Cola bottle, the romance between a bumbling scientist and a schoolteacher, and a band of guerrillas on the run. Xi and his tribe of San/Bushmen relatives are living well off the land in the Kalahari Desert. They are happy because the gods have provided plenty of everything, and no one in the tribe has unfulfilled wants. One day, a glass Coca-Cola bottle is thrown out of an aeroplane and falls to earth unbroken. Initially, this strange artifact seems to be another boon from the gods—-Xi\'s people find many uses for it. But unlike anything that they have had before, there is only one bottle to go around. This exposes the tribe to a hitherto unknown phenomenon, property, and they soon find themselves experiencing things they never had before: jealousy, envy, anger, hatred, even violence. Since it has caused the tribe unhappiness on two occasions, Xi decides that the bottle is an evil thing and must be thrown off of the edge of the world. He sets out alone on his quest and encounters Western civilization for the first time. The film presents an interpretation of civilization as viewed through Xi\'s perceptions. There are also plot lines about shy biologist Andrew Steyn who is studying the local animals ; the newly hired village school teacher, a former newspaper reporter named Kate Thompson; and some guerrillas led by Sam Boga, who are being pursued by government troops after an unsuccessful attempt to massacre the Cabinet of "Barani" and the president. Also taking a share of the limelight is Steyn\'s Land Rover, dubbed the Antichrist  by his assistant and mechanic, M\'pudi  . Also part of the chaos is an impudent safari tour guide named Jack Hind, who has designs on Thompson and often steals Steyn\'s thunder. Xi happens upon a farm and, being hungry as well as oblivious to the concept of ownership, shoots a goat with a tranquilizer arrow. For this he is arrested and jailed for stealing livestock. M\'pudi, who lived with the Bushmen for a long time and speaks Xi\'s language, realizes that Xi will die in the alien environment of a prison cell, and he and Steyn manage to hire Xi as a tracker for the 11 remaining weeks of his prison sentence. Meanwhile, the guerrillas invade the school where Kate teaches and use her and her pupils as human shields for their escape by foot to the neighboring country and threaten to kill the children if they see one soldier. Steyn, M\'pudi and Xi, who are unwittingly observing the local wildlife within the terrorists\' chosen path, manage to immobilize the guerrillas as they are passing by and save Kate and the children. Steyn allows Xi to leave to continue his quest to the edge of the world, and subsequently he and Kate become romantically involved. Xi eventually finds himself at the top of a cliff with a solid layer of low-lying clouds obscuring the landscape below. This convinces Xi that he has reached the edge of the world, and he throws the bottle off the cliff (this scene was filmed at God\'s Window in Eastern Transvaal, South Africa . Xi then returns to his band and a warm welcome from his family.'

# %%
# collect unigrams
# case fold, stop word removal, punctuation removal  
def remove_token(token): 
  return token.text.isspace() or token.is_stop or token.is_punct


def tokenize(summ):
  return [token.lemma_.lower() for token in nlp(summ) if not remove_token(token)]


def tokenize_sentence(sentences): 
  tokenized = []
  for sent in sentences: 
    tokenized.append([token.lemma_.lower() for token in nlp(sent) if not remove_token(token)])

  return tokenized

# %%
import nltk 
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\PC\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import multiprocessing as mp

mp.cpu_count()
# Out:
# 12

# %%
import multiprocessing as mp

with mp.Pool(mp.cpu_count() - 4) as pool:
    df['unigrams'] = df.summary.apply(tokenize)
    df['sentences'] = df.summary.apply(nltk.sent_tokenize)
    df['lem_sent'] = df.sentences.apply(tokenize_sentence)

df
# Out:
#        wikipedia id                                         movie name  \
# 0            975900                                     Ghosts of Mars
# 3          18998739                          The Sorcerer's Apprentice
# 4           6631279                                        Little city
# 7          11250635                            The Mechanical Monsters
# 8             77856                                       Mary Poppins
# ...             ...                                                ...
# 42198      26482675                                     Eşrefpaşalılar
# 42199      23851782                                    The Ghost Train
# 42201      34980460                                            Knuckle
# 42202        913762  The Super Dimension Fortress Macross II: Lover...
# 42203      12476867                                            Spliced
#
#                                                   genres  \
# 0      [action, adventure, thriller, horror, science ...
# 3             [adventure, family, world cinema, fantasy]
# 4                               [drama, comedy, romance]
# 7      [action, adventure, family, short film, scienc...
# 8                       [drama, comedy, family, fantasy]
# ...                                                  ...
# 42198                                    [drama, comedy]
# 42199                          [comedy, crime, thriller]
# 42201                               [drama, documentary]
# 42202    [drama, adventure, short film, science fiction]
# 42203                                 [thriller, horror]
#
#                                                  summary  \
# 0      Set in the second half of the 22nd century, th...
# 3      Every hundred years, the evil Morgana  returns...
# 4      Adam, a San Francisco-based artist who works a...
# 7       The story starts as one of the robots flies i...
# 8      The film opens with Mary Poppins  perched in a...
# ...                                                  ...
# 42198  The film is about two friends, Tayyar , a mafi...
# 42199  {{plot}} The film opens with a Great Western e...
# 42201  {{No plot}} This film follows 12 years in the ...
# 42202  The story takes place in the year 2092,The Sup...
# 42203  The movie is about a teenage girl who loves ho...
#
#                                                 unigrams  \
# 0      [set, second, half, 22nd, century, film, depic...
# 3      [year, evil, morgana, return, claim, fingall, ...
# 4      [adam, san, francisco, base, artist, work, cab...
# 7      [story, start, robot, fly, scientist, secret, ...
# 8      [film, open, mary, poppins, perch, cloud, high...
# ...                                                  ...
# 42198  [film, friend, tayyar, mafia, leader, davut, n...
# 42199  [plot, film, open, great, western, express, sp...
# 42201  [plot, film, follow, 12, year, life, 3, irish,...
# 42202  [story, take, place, year, 2092,the, super, di...
# 42203  [movie, teenage, girl, love, horror, movie, wa...
#
#                                                sentences  \
# 0      [Set in the second half of the 22nd century, t...
# 3      [Every hundred years, the evil Morgana  return...
# 4      [Adam, a San Francisco-based artist who works ...
# 7      [ The story starts as one of the robots flies ...
# 8      [The film opens with Mary Poppins  perched in ...
# ...                                                  ...
# 42198  [The film is about two friends, Tayyar , a maf...
# 42199  [{{plot}} The film opens with a Great Western ...
# 42201  [{{No plot}} This film follows 12 years in the...
# 42202  [The story takes place in the year 2092,The Su...
# 42203  [The movie is about a teenage girl who loves h...
#
#                                                 lem_sent
# 0      [[set, second, half, 22nd, century, film, depi...
# 3      [[year, evil, morgana, return, claim, fingall,...
# 4      [[adam, san, francisco, base, artist, work, ca...
# 7      [[story, start, robot, fly, scientist, secret,...
# 8      [[film, open, mary, poppins, perch, cloud, hig...
# ...                                                  ...
# 42198  [[film, friend, tayyar, mafia, leader, davut, ...
# 42199  [[plot, film, open, great, western, express, s...
# 42201  [[plot, film, follow, 12, year, life, 3, irish...
# 42202  [[story, take, place, year, 2092,the, super, d...
# 42203  [[movie, teenage, girl, love, horror, movie, w...
#
# [26088 rows x 7 columns]

# %%
# example tokenization
df.loc[42199]['unigrams']
# Out:
# ['plot',
#  'film',
#  'open',
#  'great',
#  'western',
#  'express',
#  'speeding',
#  'box',
#  'tunnel',
#  'route',
#  'cornwall',
#  'train',
#  'passenger',
#  'include',
#  'herbert',
#  'edna',
#  'young',
#  'couple',
#  'travel',
#  'truro',
#  'marry',
#  'miss',
#  'bourne',
#  'west',
#  'london',
#  'spinster',
#  'visit',
#  'evacuated',
#  'relative',
#  'tommy',
#  'gander',
#  'overenthusiastic',
#  'vaudeville',
#  'style',
#  'comedian',
#  'entertainer',
#  'head',
#  'pier',
#  'pavilion',
#  'newquay',
#  'dr',
#  'sterling',
#  'locum',
#  'doctor',
#  'redruth',
#  'richard',
#  'g',
#  'winthrop',
#  'cousin',
#  'jackie',
#  'head',
#  'truro',
#  'teddy',
#  'deakin',
#  'pass',
#  'teignmouth',
#  'communication',
#  'cord',
#  'pull',
#  'train',
#  'stop',
#  'guard',
#  'passenger',
#  'find',
#  'gander',
#  'lose',
#  'hat',
#  'run',
#  'retrieve',
#  'ignorant',
#  'delay',
#  'cause',
#  'return',
#  'train',
#  'come',
#  'jackie',
#  'winthrop',
#  'compartment',
#  'gander',
#  'try',
#  'conversation',
#  'teddy',
#  'eye',
#  'jackie',
#  'quick',
#  'try',
#  'send',
#  'packing',
#  'point',
#  'insinuate',
#  'gander',
#  'class',
#  'carriage',
#  'class',
#  'ticket',
#  'gander',
#  'jokingly',
#  'retort',
#  'say',
#  'platform',
#  'ticket',
#  'richard',
#  'time',
#  'annoy',
#  'pace',
#  'forth',
#  'outside',
#  'compartment',
#  'gander',
#  'make',
#  'silly',
#  'face',
#  'richard',
#  'lose',
#  'patience',
#  'shut',
#  'blind',
#  'window',
#  'train',
#  'arrive',
#  'fal',
#  'vale',
#  'junction',
#  'cornwall',
#  'teddy',
#  'gander',
#  'quick',
#  'help',
#  'jackie',
#  'luggage',
#  'gander',
#  'offer',
#  'share',
#  'compartment',
#  'teddy',
#  'point',
#  'travel',
#  'class',
#  'richard',
#  'dislike',
#  'comedian',
#  'instead',
#  'set',
#  'help',
#  'miss',
#  'bourne',
#  'initially',
#  'mistake',
#  'carriage',
#  'window',
#  'door',
#  'luggage',
#  'include',
#  'pet',
#  'parrot',
#  'polly',
#  'train',
#  'leave',
#  'gander',
#  'realise',
#  'forget',
#  'basket',
#  'contain',
#  'prop',
#  'costume',
#  'annoy',
#  'guard',
#  'tell',
#  'throw',
#  'van',
#  'train',
#  'leave',
#  'passenger',
#  'meet',
#  'fal',
#  'vale',
#  'stationmaster',
#  'saul',
#  'hodgkin',
#  'tell',
#  'truro',
#  'bind',
#  'train',
#  'go',
#  'will',
#  'morning',
#  'lock',
#  'night',
#  'richard',
#  'irate',
#  'prompt',
#  'know',
#  'rehearse',
#  'newquay',
#  'morning',
#  'gander',
#  'try',
#  'charter',
#  'special',
#  'saul',
#  'refuse',
#  'arrangement',
#  'prepare',
#  'bicycle',
#  'rain',
#  'start',
#  'fall',
#  'passenger',
#  'station',
#  'waiting',
#  'room',
#  'take',
#  'frustration',
#  'gander',
#  'lost',
#  'hat',
#  'saul',
#  'try',
#  'clear',
#  'stay',
#  'passenger',
#  'insist',
#  'stay',
#  'transport',
#  'arrange',
#  'eventually',
#  'saul',
#  'telephone',
#  'bus',
#  'reason',
#  'unable',
#  'requisition',
#  'suggest',
#  'walk',
#  'local',
#  'village',
#  'passenger',
#  'object',
#  'hear',
#  'mile',
#  'away',
#  'meantime',
#  'gander',
#  'rescue',
#  'basket',
#  'rain',
#  'borrow',
#  'ticket',
#  'office',
#  'change',
#  'room',
#  'spite',
#  'passenger',
#  'firm',
#  'decision',
#  'stay',
#  'saul',
#  'bring',
#  'leave',
#  'wish',
#  'stay',
#  'reason',
#  'station',
#  'haunt',
#  '1897',
#  'branch',
#  'line',
#  'run',
#  'fal',
#  'vale',
#  'junction',
#  'old',
#  'port',
#  'cross',
#  'river',
#  'swing',
#  'bridge',
#  'end',
#  'tunnel',
#  'close',
#  'station',
#  'swing',
#  'bridge',
#  'work',
#  'wheel',
#  'platform',
#  'keep',
#  'open',
#  'china',
#  'clay',
#  'boat',
#  'close',
#  'train',
#  'cross',
#  'day',
#  'local',
#  'charter',
#  'special',
#  'train',
#  'home',
#  'stationmaster',
#  'ted',
#  'holmes',
#  'keep',
#  'late',
#  'night',
#  'duty',
#  'close',
#  'bridge',
#  "o'clock",
#  'go',
#  'close',
#  'bridge',
#  'heart',
#  'attack',
#  'finish',
#  'try',
#  'office',
#  'warn',
#  'truro',
#  'bridge',
#  'heart',
#  'fail',
#  'collapse',
#  'lamp',
#  'burn',
#  'hand',
#  'holmes',
#  'dead',
#  'bridge',
#  'open',
#  'way',
#  'prevent',
#  'crash',
#  'warn',
#  'train',
#  'driver',
#  'ben',
#  'isaacs',
#  'danger',
#  'unable',
#  'stop',
#  'train',
#  'plunge',
#  'open',
#  'bridge',
#  'river',
#  'branch',
#  'line',
#  'supposedly',
#  'close',
#  'bridge',
#  'remain',
#  'open',
#  'position',
#  'day',
#  'saul',
#  'explain',
#  'occasion',
#  'train',
#  'hear',
#  'desperately',
#  'try',
#  'pull',
#  'near',
#  'station',
#  'arrive',
#  'start',
#  'truro',
#  'say',
#  'kill',
#  'look',
#  'natural',
#  'thing',
#  'ask',
#  'come',
#  'saul',
#  'reluctantly',
#  'leave',
#  'passenger',
#  'warn',
#  'look',
#  'hear',
#  'train',
#  'night',
#  'miss',
#  'bourne',
#  'shake',
#  'hear',
#  'story',
#  'richard',
#  'sceptically',
#  'pass',
#  'nonsense',
#  'gander',
#  'listen',
#  'story',
#  'make',
#  'great',
#  'fuss',
#  'order',
#  'mind',
#  'thing',
#  'richard',
#  'start',
#  'game',
#  'chess',
#  'dr',
#  'sterling',
#  'gander',
#  'try',
#  'liven',
#  'thing',
#  'singe',
#  'seaside',
#  'band',
#  'end',
#  'prematurely',
#  'richard',
#  'lose',
#  'temper',
#  'throw',
#  'gramophone',
#  'track',
#  'surprisingly',
#  'calm',
#  'act',
#  'retaliation',
#  'gander',
#  'pick',
#  'chess',
#  'set',
#  'throw',
#  'fireplace',
#  'moment',
#  'miss',
#  'bourne',
#  'hear',
#  'station',
#  'buffet',
#  'richard',
#  'go',
#  'investigate',
#  'follow',
#  'gander',
#  'pretend',
#  'try',
#  'murder',
#  'turn',
#  'worry',
#  'gander',
#  'notice',
#  'miss',
#  'bourne',
#  'tea',
#  'decide',
#  'refreshment',
#  'teddy',
#  'send',
#  'gander',
#  'fetch',
#  'water',
#  'jackie',
#  'prepare',
#  'tea',
#  'source',
#  'turn',
#  'water',
#  'crane',
#  'platform',
#  'order',
#  'stay',
#  'dry',
#  'gander',
#  'improvise',
#  'raincoat',
#  'tablecloth',
#  'sheet',
#  'tarpaulin',
#  'obtain',
#  'supply',
#  'water',
#  'find',
#  'old',
#  'bridge',
#  'wheel',
#  'curious',
#  'happen',
#  'try',
#  'turn',
#  'wheel',
#  'chain',
#  'padlock',
#  'barely',
#  'give',
#  'take',
#  'water',
#  'buffet',
#  'make',
#  'mention',
#  'wheel',
#  'teddy',
#  'jackie',
#  'tea',
#  'urne',
#  'gas',
#  'flashy',
#  'fashion',
#  'try',
#  'start',
#  'conversation',
#  'jackie',
#  'teddy',
#  'interfere',
#  'send',
#  'waiting',
#  'room',
#  'try',
#  'vain',
#  'entertain',
#  'passenger',
#  'ghost',
#  'story',
#  'teddy',
#  'jackie',
#  'soon',
#  'bring',
#  'tea',
#  'waiting',
#  'room',
#  'passenger',
#  'share',
#  'little',
#  'food',
#  'meal',
#  'midnight',
#  'meal',
#  'gander',
#  'act',
#  'ted',
#  'holmes',
#  'ghost',
#  'lie',
#  'doorway',
#  'branch',
#  'line',
#  'platform',
#  'repeatedly',
#  'stumble',
#  'ghost',
#  'trip',
#  'end',
#  'move',
#  'ghost',
#  'harm',
#  'way',
#  'offer',
#  'provide',
#  'dessert',
#  'chocolate',
#  'machine',
#  'outside',
#  'return',
#  'find',
#  'disappointment',
#  'buy',
#  'box',
#  'match',
#  'tell',
#  'story',
#  'accompany',
#  'passenger',
#  'smoke',
#  'cigarette',
#  'burn',
#  'lip',
#  'hear',
#  'footstep',
#  'outside',
#  'richard',
#  'open',
#  'door',
#  'branch',
#  'line',
#  'platform',
#  'seriously',
#  'ill',
#  'saul',
#  'hodgkin',
#  'collapse',
#  'room',
#  'gander',
#  'rush',
#  'outside',
#  'lamp',
#  'raincoat',
#  'fill',
#  'glass',
#  'water',
#  'water',
#  'crane',
#  'richard',
#  'teddy',
#  'dr',
#  'sterling',
#  'carry',
#  'saul',
#  'ticket',
#  'office',
#  'time',
#  'gander',
#  'arrive',
#  'dr',
#  'sterling',
#  'pronounce',
#  'saul',
#  'dead',
#  'edna',
#  'hear',
#  'scare',
#  'stay',
#  'station',
#  'corpse',
#  'edna',
#  'persuade',
#  'reluctant',
#  'fiancé',
#  'herbert',
#  'well',
#  'try',
#  'mother',
#  'teddy',
#  'try',
#  'police',
#  'line',
#  'appear',
#  'miss',
#  'bourne',
#  'dreadful',
#  'state',
#  'faint',
#  'saul',
#  'collapse',
#  'room',
#  'gander',
#  'borrow',
#  'bottle',
#  'brandy',
#  'dr',
#  'sterling',
#  'soothe',
#  'nerve',
#  'strict',
#  'temperance',
#  'teetotaler',
#  'miss',
#  'bourne',
#  'drink',
#  'lot',
#  'noticeably',
#  'drunk',
#  'teddy',
#  'jackie',
#  'gander',
#  'bring',
#  'buffet',
#  'sleep',
#  'gander',
#  'try',
#  'fail',
#  'comically',
#  'trick',
#  'see',
#  'hippodrome',
#  'crockery',
#  'stay',
#  'table',
#  'pull',
#  'rug',
#  'shortly',
#  'herbert',
#  'edna',
#  'burst',
#  'waiting',
#  'room',
#  'half',
#  'luggage',
#  'knock',
#  'hear',
#  'open',
#  'door',
#  'reveal',
#  'terrified',
#  'young',
#  'woman',
#  'black',
#  'stranger',
#  'plead',
#  'help',
#  'say',
#  'come',
#  'passenger',
#  'confuse',
#  'particularly',
#  'young',
#  'woman',
#  'act',
#  'know',
#  'talk',
#  'teddy',
#  'see',
#  'car',
#  'come',
#  'road',
#  'watch',
#  'car',
#  'spin',
#  'road',
#  'crash',
#  'tree',
#  'teddy',
#  'accompany',
#  'gander',
#  'dr',
#  'sterling',
#  'happen',
#  'driver',
#  'car',
#  'unhurt',
#  'car',
#  'badly',
#  'damage',
#  'turn',
#  'skid',
#  'herbert',
#  'edna',
#  'luggage',
#  'include',
#  'fender',
#  'donate',
#  'owner',
#  'furniture',
#  'shop',
#  'return',
#  'waiting',
#  'room',
#  'battered',
#  'luggage',
#  'driver',
#  'car',
#  'introduce',
#  'price',
#  'explain',
#  'come',
#  'search',
#  'sister',
#  'julia',
#  'add',
#  'suffer',
#  'delusion',
#  'normally',
#  'keep',
#  'observation',
#  'julia',
#  'overhear',
#  'emerge',
#  'buffet',
#  'protest',
#  'lie',
#  'price',
#  'explain',
#  'think',
#  'see',
#  'ghost',
#  'train',
#  'shock',
#  'retain',
#  'fascination',
#  'experience',
#  'compulsion',
#  'try',
#  'curious',
#  'hear',
#  'ghost',
#  'train',
#  'passenger',
#  'reply',
#  'saul',
#  'hodgkin',
#  'tell',
#  'lie',
#  'dead',
#  'ticket',
#  'office',
#  'price',
#  'go',
#  'look',
#  'saul',
#  'body',
#  'mysteriously',
#  'vanish',
#  'desk',
#  'way',
#  'leave',
#  'early',
#  'explain',
#  'price',
#  'happen',
#  'julia',
#  'insinuate',
#  'actually',
#  'ted',
#  'holmes',
#  'dr',
#  'sterling',
#  'suggest',
#  'julia',
#  'remain',
#  'station',
#  'realise',
#  'ghost',
#  'train',
#  'exist',
#  'price',
#  'reluctantly',
#  'concede',
#  'insist',
#  'leave',
#  'julia',
#  'come',
#  'soon',
#  'find',
#  'car',
#  'time',
#  'leave',
#  'signal',
#  'bell',
#  'hear',
#  'ring',
#  'ticket',
#  'office',
#  'follow',
#  'shriek',
#  'whistle',
#  'approach',
#  'train',
#  'teddy',
#  'richard',
#  'try',
#  'open',
#  'door',
#  'look',
#  'train',
#  'door',
#  'will',
#  'open',
#  'thunder',
#  'station',
#  'julia',
#  'smash',
#  'window',
#  'look',
#  'train',
#  'faint',
#  'moment',
#  'see',
#  'dr',
#  'sterling',
#  'make',
#  'comfortable',
#  'waiting',
#  'room',
#  'bench',
#  'request',
#  'glass',
#  'water',
#  'teddy',
#  'gander',
#  'suspect',
#  'trouble',
#  'opportunity',
#  'outside',
#  'sleuthing',
#  'rain',
#  'stop',
#  'gander',
#  'surprised',
#  'find',
#  'saul',
#  'lamp',
#  'vanish',
#  'surprise',
#  'come',
#  'teddy',
#  'find',
#  'bridge',
#  'close',
#  'hear',
#  'singe',
#  'tunnel',
#  'mouth',
#  'look',
#  'wander',
#  'julia',
#  'hear',
#  'waiting',
#  'room',
#  'claim',
#  'ben',
#  'isaacs',
#  'sole',
#  'survivor',
#  'accident',
#  'come',
#  'accident',
#  'mind',
#  'singe',
#  'rock',
#  'ages',
#  'teddy',
#  'know',
#  'well',
#  'shoot',
#  'ghost',
#  'cause',
#  'flee',
#  'tunnel',
#  'gander',
#  'run',
#  'teddy',
#  'spot',
#  'sheet',
#  'cloth',
#  'drop',
#  'blood',
#  'head',
#  'waiting',
#  'room',
#  'gander',
#  'realise',
#  'teddy',
#  'distraction',
#  'way',
#  'tunnel',
#  'price',
#  'manage',
#  'requisition',
#  'bus',
#  'perplexed',
#  'hear',
#  'richard',
#  'idiot',
#  'fool',
#  'gun',
#  'outside',
#  'moment',
#  'teddy',
#  'enter',
#  'room',
#  'hold',
#  'gunpoint',
#  'lock',
#  'door',
#  'show',
#  'bloodstained',
#  'cloth',
#  'begin',
#  'explain',
#  'hoax',
#  'ghost',
#  'train',
#  'take',
#  'advantage',
#  'accident',
#  'local',
#  'superstition',
#  'job',
#  'easy',
#  'work',
#  'fellow',
#  'passenger',
#  'ghost',
#  'train',
#  'add',
#  'happen',
#  'real',
#  'plymouth',
#  'express',
#  'elaborate',
#  'jackie',
#  'point',
#  'gander',
#  'reason',
#  'place',
#  'teddy',
#  'take',
#  'guard',
#  'allow',
#  'richard',
#  'punch',
#  ...]

# %%
# mean number of tokens in summary 
df.unigrams.str.len().mean()

# keep obs with at least 75 tkens
df = df[df.unigrams.map(len) >= 75]

# %%
df_new2 = df

def get_drama_comedy_action_thriller(genres):
  for gen in genres:
    if gen=="drama":
      return gen
    elif gen=="comedy":
      return gen
    elif gen=="action":
      return gen
    elif gen=="thriller":
      return gen
    else:
      return 0

df_new["genre_new"] = df_new.genres.apply(get_drama_comedy_action_thriller)

# %%
df_drama = df_new2[df_new2["genre_new"] == "drama"]
df_drama_subset = df_drama.sample(500)

df_comedy = df_new2[df_new2["genre_new"] == "comedy"]
df_comedy_subset = df_comedy.sample(500)

df_action = df_new2[df_new2["genre_new"] == "action"]
df_action_subset = df_action.sample(500)

df_thriller = df_new2[df_new2["genre_new"] == "thriller"]
df_thriller_subset = df_thriller.sample(500)

df_new2 = df_new[df_new["genre_new"] != 0]

df_concat = pd.concat([df_drama_subset, df_comedy_subset, df_action_subset, df_thriller_subset])

# %%
def flatten_sent(sentences):
  return [" ".join(sent) for sent in sentences]

df_concat["lem_sent_join"] = df_concat.lem_sent.apply(flatten_sent)

df_concat
# Out:
#        wikipedia id                        movie name  \
# 36084        431014                          Big Fish
# 16224      18057739              (500) Days of Summer
# 24779      20475363                       The Tempest
# 28017      17941264  Poison Ivy 4: The Secret Society
# 5778       32930644                       Blood Money
# ...             ...                               ...
# 29042       3210534                               Saw
# 27086       6811111                     The Scarecrow
# 35902      11527681                               ELI
# 16790       4306261                        The Eye 10
# 36938      33341963                         Nurse 3-D
#
#                                             genres  \
# 36084  [drama, comedy, adventure, family, fantasy]
# 16224                     [drama, comedy, romance]
# 24779                     [drama, comedy, fantasy]
# 28017                   [drama, thriller, fantasy]
# 5778                     [drama, action, thriller]
# ...                                            ...
# 29042               [thriller, horror, short film]
# 27086                  [thriller, horror, mystery]
# 35902      [thriller, short film, science fiction]
# 16790             [thriller, world cinema, horror]
# 36938                           [thriller, horror]
#
#                                                  summary  \
# 36084  At his son's wedding party, Edward Bloom  tell...
# 16224  The film is presented in a nonlinear narrative...
# 24779  Prospera, the duchess of Milan, is usurped by ...
# 28017  Danielle "Daisy" Brookes is an orphan who leav...
# 5778   The story is about Kunal  who believes he can ...
# ...                                                  ...
# 29042  A young man, David , is in an interrogation ro...
# 27086  One night a girl is slain in the woods of a sm...
# 35902  A man wakes up in a hospital, lying on an oper...
# 16790  In Thailand, Chong-kwai welcomes his friends T...
# 36938  Abby Russell  is a dedicated nurse during the ...
#
#                                                 unigrams  \
# 36084  [son, wedding, party, edward, bloom, tell, tal...
# 16224  [film, present, nonlinear, narrative, jump, da...
# 24779  [prospera, duchess, milan, usurp, brother, ant...
# 28017  [danielle, daisy, brookes, orphan, leave, ranc...
# 5778   [story, kunal, believe, try, hard, receive, jo...
# ...                                                  ...
# 29042  [young, man, david, interrogation, room, talk,...
# 27086  [night, girl, slay, wood, small, town, teenage...
# 35902  [man, wake, hospital, lie, operating, table, i...
# 16790  [thailand, chong, kwai, welcome, friend, ted, ...
# 36938  [abby, russell, dedicated, nurse, day, night, ...
#
#                                                sentences  \
# 36084  [At his son's wedding party, Edward Bloom  tel...
# 16224  [The film is presented in a nonlinear narrativ...
# 24779  [Prospera, the duchess of Milan, is usurped by...
# 28017  [Danielle "Daisy" Brookes is an orphan who lea...
# 5778   [The story is about Kunal  who believes he can...
# ...                                                  ...
# 29042  [A young man, David , is in an interrogation r...
# 27086  [One night a girl is slain in the woods of a s...
# 35902  [A man wakes up in a hospital, lying on an ope...
# 16790  [In Thailand, Chong-kwai welcomes his friends ...
# 36938  [Abby Russell  is a dedicated nurse during the...
#
#                                                 lem_sent genre_new  \
# 36084  [[son, wedding, party, edward, bloom, tell, ta...     drama
# 16224  [[film, present, nonlinear, narrative, jump, d...     drama
# 24779  [[prospera, duchess, milan, usurp, brother, an...     drama
# 28017  [[danielle, daisy, brookes, orphan, leave, ran...     drama
# 5778   [[story, kunal, believe, try, hard], [receive,...     drama
# ...                                                  ...       ...
# 29042  [[young, man, david, interrogation, room, talk...  thriller
# 27086  [[night, girl, slay, wood, small, town, teenag...  thriller
# 35902  [[man, wake, hospital, lie, operating, table],...  thriller
# 16790  [[thailand, chong, kwai, welcome, friend, ted,...  thriller
# 36938  [[abby, russell, dedicated, nurse, day, night,...  thriller
#
#                                            lem_sent_join
# 36084  [son wedding party edward bloom tell tale tell...
# 16224  [film present nonlinear narrative jump day 500...
# 24779  [prospera duchess milan usurp brother antonio ...
# 28017  [danielle daisy brookes orphan leave ranch boy...
# 5778   [story kunal believe try hard, receive job off...
# ...                                                  ...
# 29042  [young man david interrogation room talk unnam...
# 27086  [night girl slay wood small town teenager sam ...
# 35902  [man wake hospital lie operating table, idea r...
# 16790  [thailand chong kwai welcome friend ted kofei ...
# 36938  [abby russell dedicated nurse day night true c...
#
# [2000 rows x 9 columns]

# %%
# prepare df for exporting 


# drop unneeded cols 
df_concat = df_concat.drop(['wikipedia id', 'movie name', 'genres'], axis = 1).reset_index(drop = True)


# reorder cols 
df_concat = df_concat[['summary', 'unigrams', 'sentences', 'lem_sent', 'lem_sent_join', 'genre_new']]

df_concat
# Out:
#                                                 summary  \
# 0     At his son's wedding party, Edward Bloom  tell...
# 1     The film is presented in a nonlinear narrative...
# 2     Prospera, the duchess of Milan, is usurped by ...
# 3     Danielle "Daisy" Brookes is an orphan who leav...
# 4     The story is about Kunal  who believes he can ...
# ...                                                 ...
# 1995  A young man, David , is in an interrogation ro...
# 1996  One night a girl is slain in the woods of a sm...
# 1997  A man wakes up in a hospital, lying on an oper...
# 1998  In Thailand, Chong-kwai welcomes his friends T...
# 1999  Abby Russell  is a dedicated nurse during the ...
#
#                                                unigrams  \
# 0     [son, wedding, party, edward, bloom, tell, tal...
# 1     [film, present, nonlinear, narrative, jump, da...
# 2     [prospera, duchess, milan, usurp, brother, ant...
# 3     [danielle, daisy, brookes, orphan, leave, ranc...
# 4     [story, kunal, believe, try, hard, receive, jo...
# ...                                                 ...
# 1995  [young, man, david, interrogation, room, talk,...
# 1996  [night, girl, slay, wood, small, town, teenage...
# 1997  [man, wake, hospital, lie, operating, table, i...
# 1998  [thailand, chong, kwai, welcome, friend, ted, ...
# 1999  [abby, russell, dedicated, nurse, day, night, ...
#
#                                               sentences  \
# 0     [At his son's wedding party, Edward Bloom  tel...
# 1     [The film is presented in a nonlinear narrativ...
# 2     [Prospera, the duchess of Milan, is usurped by...
# 3     [Danielle "Daisy" Brookes is an orphan who lea...
# 4     [The story is about Kunal  who believes he can...
# ...                                                 ...
# 1995  [A young man, David , is in an interrogation r...
# 1996  [One night a girl is slain in the woods of a s...
# 1997  [A man wakes up in a hospital, lying on an ope...
# 1998  [In Thailand, Chong-kwai welcomes his friends ...
# 1999  [Abby Russell  is a dedicated nurse during the...
#
#                                                lem_sent  \
# 0     [[son, wedding, party, edward, bloom, tell, ta...
# 1     [[film, present, nonlinear, narrative, jump, d...
# 2     [[prospera, duchess, milan, usurp, brother, an...
# 3     [[danielle, daisy, brookes, orphan, leave, ran...
# 4     [[story, kunal, believe, try, hard], [receive,...
# ...                                                 ...
# 1995  [[young, man, david, interrogation, room, talk...
# 1996  [[night, girl, slay, wood, small, town, teenag...
# 1997  [[man, wake, hospital, lie, operating, table],...
# 1998  [[thailand, chong, kwai, welcome, friend, ted,...
# 1999  [[abby, russell, dedicated, nurse, day, night,...
#
#                                           lem_sent_join genre_new
# 0     [son wedding party edward bloom tell tale tell...     drama
# 1     [film present nonlinear narrative jump day 500...     drama
# 2     [prospera duchess milan usurp brother antonio ...     drama
# 3     [danielle daisy brookes orphan leave ranch boy...     drama
# 4     [story kunal believe try hard, receive job off...     drama
# ...                                                 ...       ...
# 1995  [young man david interrogation room talk unnam...  thriller
# 1996  [night girl slay wood small town teenager sam ...  thriller
# 1997  [man wake hospital lie operating table, idea r...  thriller
# 1998  [thailand chong kwai welcome friend ted kofei ...  thriller
# 1999  [abby russell dedicated nurse day night true c...  thriller
#
# [2000 rows x 6 columns]

# %%
# export 
df_concat.to_csv('./processed_dataframe.csv')

# %%
pwd
# Out:
# 'C:\\Users\\PC\\Downloads'
